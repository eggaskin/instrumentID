# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %%
# read in data
pred_df = pd.read_csv('triple_predictions.csv')

# Get a counter for each instrument. Ex: How many "violin" values are there?
pred_df_actual_count = Counter(pred_df['Actual'])
pred_df_actual_count
# Out:
# Counter({'violin': 1699,
#          'piano': 1359,
#          'flute': 1289,
#          'clarinet': 1066,
#          'trumpet': 550,
#          'cello': 527,
#          'voice': 497,
#          'guitar_electric': 492,
#          'sax_soprano': 235,
#          'sax_tenor': 218,
#          'sax_alto': 157,
#          'piccolo': 154,
#          'guitar_acoustic': 145,
#          'organ': 133,
#          'saxophone': 117,
#          'sax_baritone': 92,
#          'oboe': 84,
#          'bass': 33})

# %%
# list of lists with wrong prediction and truth
incorrect = []

# list of lists with wrong prediction and name of file, which has the name of the played instrument
actual_filename = []
for pred, actual, file_name in zip(pred_df['0'], pred_df['Actual'], pred_df['Filename']):
    if pred != actual:
        incorrect.append([pred, actual])
        actual_filename.append([pred, file_name])

print('Number of incorrect predictions:', len(incorrect))
print('Accuracy:', 1 - len(incorrect) / len(pred_df))
# Out:
# Number of incorrect predictions: 1804
# Accuracy: 0.7960890697411552

# %%
# get the number of each instrument that was classified incorrectly
incorrect_actual = [actual[1] for actual in incorrect]
incorrect_actual_count = Counter(incorrect_actual)
incorrect_actual_count
# Out:
# Counter({'flute': 215,
#          'clarinet': 213,
#          'violin': 188,
#          'trumpet': 148,
#          'guitar_acoustic': 130,
#          'voice': 128,
#          'piano': 125,
#          'guitar_electric': 120,
#          'saxophone': 104,
#          'sax_soprano': 100,
#          'sax_tenor': 70,
#          'organ': 70,
#          'cello': 60,
#          'sax_alto': 48,
#          'sax_baritone': 27,
#          'oboe': 27,
#          'piccolo': 23,
#          'bass': 8})

# %%
## create dictionaries that have the same key order
# order the incorrect_actual_count Counter object
rearranged_incorrect_actual_count = {key: incorrect_actual_count[key] for key in list(pred_df_actual_count.keys())}

# order the pred_df_actual_count Counter object
rearranged_pred_df_actual_count = {key: pred_df_actual_count[key] for key in list(pred_df_actual_count.keys())}
rearranged_incorrect_actual_count
# Out:
# {'piccolo': 23,
#  'violin': 188,
#  'guitar_acoustic': 130,
#  'voice': 128,
#  'piano': 125,
#  'bass': 8,
#  'flute': 215,
#  'trumpet': 148,
#  'sax_tenor': 70,
#  'guitar_electric': 120,
#  'clarinet': 213,
#  'saxophone': 104,
#  'organ': 70,
#  'cello': 60,
#  'sax_alto': 48,
#  'sax_soprano': 100,
#  'sax_baritone': 27,
#  'oboe': 27}

# %%
rearranged_pred_df_actual_count
# Out:
# {'piccolo': 154,
#  'violin': 1699,
#  'guitar_acoustic': 145,
#  'voice': 497,
#  'piano': 1359,
#  'bass': 33,
#  'flute': 1289,
#  'trumpet': 550,
#  'sax_tenor': 218,
#  'guitar_electric': 492,
#  'clarinet': 1066,
#  'saxophone': 117,
#  'organ': 133,
#  'cello': 527,
#  'sax_alto': 157,
#  'sax_soprano': 235,
#  'sax_baritone': 92,
#  'oboe': 84}

# %%
# dictionary of error rate for each instrument
errors_dict = {}
for instrument, count in rearranged_pred_df_actual_count.items():
    errors_dict[instrument] = rearranged_incorrect_actual_count[instrument] / count

# data frame in descending order by error rate
errors_df = pd.DataFrame(errors_dict.items(), columns=['Instrument', 'Error Rate']).sort_values(by='Error Rate', ascending=False)
errors_df
# Out:
#          Instrument  Error Rate
# 2   guitar_acoustic    0.896552
# 11        saxophone    0.888889
# 12            organ    0.526316
# 15      sax_soprano    0.425532
# 17             oboe    0.321429
# 8         sax_tenor    0.321101
# 14         sax_alto    0.305732
# 16     sax_baritone    0.293478
# 7           trumpet    0.269091
# 3             voice    0.257545
# 9   guitar_electric    0.243902
# 5              bass    0.242424
# 10         clarinet    0.199812
# 6             flute    0.166796
# 0           piccolo    0.149351
# 13            cello    0.113852
# 1            violin    0.110653
# 4             piano    0.091979

# %%
actual_filename
# Out:
# [['piano', 'guitar_acoustic-irmas-3984.wav'],
#  ['guitar_electric', 'voice-irmas-883.wav'],
#  ['clarinet', 'flute-medley_solos-1286.wav'],
#  ['clarinet', 'flute-medley_solos-4252.wav'],
#  ['guitar_electric', 'voice-irmas-1322.wav'],
#  ['flute', 'piccolo-good_sounds-008865.wav'],
#  ['piano', 'saxophone-irmas-2385.wav'],
#  ['cello', 'guitar_acoustic-irmas-4525.wav'],
#  ['flute', 'clarinet-medley_solos-9147.wav'],
#  ['clarinet', 'flute-medley_solos-3702.wav'],
#  ['guitar_electric', 'violin-good_sounds-016092.wav'],
#  ['flute', 'piccolo-good_sounds-008860.wav'],
#  ['cello', 'saxophone-irmas-2665.wav'],
#  ['guitar_electric', 'clarinet-irmas-3445.wav'],
#  ['clarinet', 'flute-good_sounds-006983.wav'],
#  ['sax_soprano', 'sax_alto-good_sounds-009496.wav'],
#  ['sax_baritone', 'sax_soprano-good_sounds-011283.wav'],
#  ['flute', 'piano-medley_solos-18241.wav'],
#  ['clarinet', 'piano-medley_solos-20187.wav'],
#  ['sax_baritone', 'sax_tenor-medley_solos-5705.wav'],
#  ['flute', 'clarinet-medley_solos-17682.wav'],
#  ['cello', 'flute-good_sounds-006979.wav'],
#  ['guitar_electric', 'saxophone-irmas-2202.wav'],
#  ['organ', 'guitar_acoustic-irmas-4299.wav'],
#  ['voice', 'flute-irmas-5370.wav'],
#  ['voice', 'guitar_acoustic-irmas-4435.wav'],
#  ['piano', 'saxophone-irmas-2348.wav'],
#  ['voice', 'piano-irmas-216.wav'],
#  ['flute', 'violin-good_sounds-015659.wav'],
#  ['flute', 'organ-irmas-3221.wav'],
#  ['violin', 'sax_baritone-good_sounds-010693.wav'],
#  ['flute', 'clarinet-medley_solos-11570.wav'],
#  ['violin', 'clarinet-good_sounds-002686.wav'],
#  ['guitar_electric', 'voice-irmas-1107.wav'],
#  ['clarinet', 'trumpet-good_sounds-012770.wav'],
#  ['violin', 'saxophone-irmas-2361.wav'],
#  ['flute', 'organ-irmas-3247.wav'],
#  ['voice', 'violin-irmas-4764.wav'],
#  ['trumpet', 'oboe-good_sounds-008200.wav'],
#  ['guitar_electric', 'organ-irmas-2999.wav'],
#  ['violin', 'trumpet-medley_solos-6225.wav'],
#  ['violin', 'piano-medley_solos-21503.wav'],
#  ['cello', 'piano-irmas-321.wav'],
#  ['cello', 'piano-irmas-8.wav'],
#  ['organ', 'trumpet-irmas-1912.wav'],
#  ['trumpet', 'clarinet-irmas-3645.wav'],
#  ['organ', 'guitar_electric-irmas-5560.wav'],
#  ['oboe', 'clarinet-good_sounds-003553.wav'],
#  ['organ', 'guitar_electric-irmas-6041.wav'],
#  ['piano', 'guitar_acoustic-irmas-4472.wav'],
#  ['flute', 'violin-good_sounds-016302.wav'],
#  ['sax_baritone', 'trumpet-good_sounds-013601.wav'],
#  ['sax_tenor', 'flute-good_sounds-006741.wav'],
#  ['piano', 'trumpet-good_sounds-013943.wav'],
#  ['trumpet', 'organ-irmas-3223.wav'],
#  ['flute', 'violin-good_sounds-015182.wav'],
#  ['cello', 'flute-irmas-5458.wav'],
#  ['piano', 'saxophone-irmas-2177.wav'],
#  ['clarinet', 'trumpet-good_sounds-014348.wav'],
#  ['violin', 'voice-irmas-868.wav'],
#  ['guitar_electric', 'piano-irmas-109.wav'],
#  ['voice', 'flute-medley_solos-11207.wav'],
#  ['cello', 'guitar_acoustic-irmas-4255.wav'],
#  ['organ', 'voice-irmas-1340.wav'],
#  ['clarinet', 'flute-irmas-5534.wav'],
#  ['cello', 'clarinet-good_sounds-003432.wav'],
#  ['flute', 'piccolo-good_sounds-008932.wav'],
#  ['trumpet', 'sax_tenor-good_sounds-012537.wav'],
#  ['sax_baritone', 'sax_tenor-good_sounds-012436.wav'],
#  ['clarinet', 'sax_tenor-medley_solos-18228.wav'],
#  ['organ', 'guitar_acoustic-irmas-4024.wav'],
#  ['guitar_electric', 'organ-irmas-3111.wav'],
#  ['cello', 'guitar_acoustic-irmas-4383.wav'],
#  ['violin', 'voice-irmas-1284.wav'],
#  ['clarinet', 'flute-medley_solos-7425.wav'],
#  ['violin', 'voice-medley_solos-7326.wav'],
#  ['guitar_electric', 'organ-irmas-2867.wav'],
#  ['clarinet', 'oboe-good_sounds-008363.wav'],
#  ['clarinet', 'piano-medley_solos-16762.wav'],
#  ['flute', 'piano-irmas-363.wav'],
#  ['guitar_electric', 'sax_tenor-good_sounds-010325.wav'],
#  ['piano', 'flute-medley_solos-10273.wav'],
#  ['voice', 'flute-irmas-5361.wav'],
#  ['violin', 'sax_tenor-medley_solos-8005.wav'],
#  ['sax_tenor', 'violin-good_sounds-016088.wav'],
#  ['clarinet', 'sax_tenor-medley_solos-7304.wav'],
#  ['piccolo', 'flute-good_sounds-006272.wav'],
#  ['cello', 'organ-irmas-2708.wav'],
#  ['clarinet', 'piano-medley_solos-17054.wav'],
#  ['violin', 'voice-medley_solos-7982.wav'],
#  ['clarinet', 'oboe-good_sounds-008240.wav'],
#  ['clarinet', 'flute-medley_solos-10129.wav'],
#  ['sax_alto', 'voice-medley_solos-15218.wav'],
#  ['sax_tenor', 'flute-irmas-5417.wav'],
#  ['cello', 'flute-medley_solos-10663.wav'],
#  ['cello', 'voice-irmas-789.wav'],
#  ['trumpet', 'sax_soprano-good_sounds-011103.wav'],
#  ['guitar_electric', 'clarinet-irmas-3524.wav'],
#  ['flute', 'clarinet-good_sounds-003693.wav'],
#  ['guitar_electric', 'piano-irmas-594.wav'],
#  ['voice', 'trumpet-medley_solos-11633.wav'],
#  ['clarinet', 'piano-medley_solos-19189.wav'],
#  ['guitar_electric', 'sax_tenor-medley_solos-10705.wav'],
#  ['flute', 'sax_baritone-good_sounds-010665.wav'],
#  ['flute', 'trumpet-good_sounds-013017.wav'],
#  ['voice', 'guitar_acoustic-irmas-4496.wav'],
#  ['piano', 'saxophone-irmas-2363.wav'],
#  ['sax_baritone', 'flute-medley_solos-17528.wav'],
#  ['guitar_electric', 'organ-irmas-3257.wav'],
#  ['cello', 'violin-irmas-4666.wav'],
#  ['guitar_electric', 'saxophone-irmas-2276.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011722.wav'],
#  ['violin', 'cello-good_sounds-002182.wav'],
#  ['violin', 'flute-irmas-5275.wav'],
#  ['clarinet', 'guitar_electric-irmas-5724.wav'],
#  ['sax_tenor', 'sax_soprano-good_sounds-011633.wav'],
#  ['flute', 'guitar_electric-medley_solos-21150.wav'],
#  ['cello', 'trumpet-irmas-1813.wav'],
#  ['voice', 'clarinet-irmas-3607.wav'],
#  ['flute', 'violin-good_sounds-016320.wav'],
#  ['flute', 'clarinet-good_sounds-003639.wav'],
#  ['voice', 'guitar_acoustic-irmas-4138.wav'],
#  ['saxophone', 'piano-irmas-469.wav'],
#  ['guitar_electric', 'saxophone-irmas-2142.wav'],
#  ['flute', 'cello-good_sounds-001629.wav'],
#  ['cello', 'guitar_acoustic-irmas-3906.wav'],
#  ['piano', 'violin-irmas-4965.wav'],
#  ['organ', 'guitar_acoustic-irmas-4286.wav'],
#  ['flute', 'clarinet-good_sounds-003685.wav'],
#  ['voice', 'saxophone-irmas-2632.wav'],
#  ['guitar_electric', 'organ-irmas-3208.wav'],
#  ['sax_tenor', 'flute-good_sounds-006168.wav'],
#  ['guitar_electric', 'cello-irmas-6486.wav'],
#  ['sax_soprano', 'voice-medley_solos-7236.wav'],
#  ['flute', 'violin-good_sounds-015757.wav'],
#  ['cello', 'flute-good_sounds-006534.wav'],
#  ['flute', 'trumpet-irmas-1863.wav'],
#  ['guitar_electric', 'trumpet-irmas-1999.wav'],
#  ['cello', 'guitar_acoustic-irmas-4397.wav'],
#  ['organ', 'guitar_acoustic-irmas-4221.wav'],
#  ['clarinet', 'cello-good_sounds-002232.wav'],
#  ['sax_tenor', 'trumpet-good_sounds-012891.wav'],
#  ['flute', 'violin-irmas-4808.wav'],
#  ['guitar_electric', 'voice-irmas-909.wav'],
#  ['organ', 'guitar_electric-irmas-6141.wav'],
#  ['piano', 'saxophone-irmas-2199.wav'],
#  ['guitar_electric', 'voice-irmas-814.wav'],
#  ['oboe', 'clarinet-good_sounds-002775.wav'],
#  ['flute', 'clarinet-medley_solos-20752.wav'],
#  ['flute', 'guitar_acoustic-irmas-4335.wav'],
#  ['cello', 'piano-irmas-687.wav'],
#  ['violin', 'voice-medley_solos-9037.wav'],
#  ['saxophone', 'piano-irmas-531.wav'],
#  ['flute', 'piccolo-good_sounds-008994.wav'],
#  ['voice', 'guitar_acoustic-irmas-4287.wav'],
#  ['clarinet', 'sax_alto-good_sounds-009826.wav'],
#  ['clarinet', 'piano-medley_solos-10787.wav'],
#  ['violin', 'cello-good_sounds-001752.wav'],
#  ['saxophone', 'flute-irmas-5133.wav'],
#  ['guitar_electric', 'clarinet-irmas-3547.wav'],
#  ['violin', 'piccolo-good_sounds-008680.wav'],
#  ['voice', 'guitar_acoustic-irmas-4261.wav'],
#  ['violin', 'voice-irmas-1337.wav'],
#  ['guitar_electric', 'violin-irmas-4716.wav'],
#  ['cello', 'voice-irmas-1015.wav'],
#  ['organ', 'voice-irmas-1390.wav'],
#  ['guitar_electric', 'voice-irmas-873.wav'],
#  ['voice', 'flute-irmas-5245.wav'],
#  ['guitar_electric', 'trumpet-irmas-1551.wav'],
#  ['sax_alto', 'flute-good_sounds-005786.wav'],
#  ['voice', 'guitar_acoustic-irmas-4434.wav'],
#  ['violin', 'sax_tenor-medley_solos-16674.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011749.wav'],
#  ['flute', 'organ-irmas-3348.wav'],
#  ['sax_soprano', 'voice-medley_solos-16858.wav'],
#  ['flute', 'voice-irmas-959.wav'],
#  ['clarinet', 'flute-medley_solos-18515.wav'],
#  ['guitar_acoustic', 'cello-irmas-6520.wav'],
#  ['sax_baritone', 'flute-medley_solos-21145.wav'],
#  ['flute', 'trumpet-good_sounds-013239.wav'],
#  ['flute', 'trumpet-good_sounds-013940.wav'],
#  ['oboe', 'guitar_electric-irmas-6167.wav'],
#  ['cello', 'violin-good_sounds-016311.wav'],
#  ['trumpet', 'flute-good_sounds-006837.wav'],
#  ['piano', 'violin-medley_solos-8990.wav'],
#  ['flute', 'violin-good_sounds-016564.wav'],
#  ['violin', 'piano-medley_solos-16876.wav'],
#  ['cello', 'voice-irmas-771.wav'],
#  ['guitar_acoustic', 'organ-irmas-2777.wav'],
#  ['flute', 'voice-irmas-1128.wav'],
#  ['trumpet', 'clarinet-good_sounds-004724.wav'],
#  ['clarinet', 'piano-medley_solos-19123.wav'],
#  ['clarinet', 'flute-medley_solos-16076.wav'],
#  ['violin', 'sax_soprano-good_sounds-011520.wav'],
#  ['violin', 'piano-irmas-419.wav'],
#  ['sax_baritone', 'piano-medley_solos-18107.wav'],
#  ['bass', 'trumpet-irmas-1909.wav'],
#  ['cello', 'flute-irmas-5516.wav'],
#  ['sax_tenor', 'oboe-good_sounds-008463.wav'],
#  ['guitar_electric', 'clarinet-irmas-3654.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011832.wav'],
#  ['clarinet', 'flute-good_sounds-007069.wav'],
#  ['clarinet', 'flute-good_sounds-007022.wav'],
#  ['guitar_electric', 'saxophone-irmas-2635.wav'],
#  ['voice', 'flute-irmas-5378.wav'],
#  ['organ', 'voice-irmas-917.wav'],
#  ['piano', 'guitar_electric-irmas-5704.wav'],
#  ['trumpet', 'clarinet-medley_solos-7922.wav'],
#  ['violin', 'trumpet-irmas-1537.wav'],
#  ['clarinet', 'sax_alto-good_sounds-009416.wav'],
#  ['piano', 'guitar_electric-irmas-6079.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-012072.wav'],
#  ['sax_baritone', 'violin-good_sounds-016052.wav'],
#  ['violin', 'voice-irmas-1329.wav'],
#  ['cello', 'guitar_acoustic-irmas-4521.wav'],
#  ['flute', 'violin-good_sounds-015640.wav'],
#  ['clarinet', 'piccolo-good_sounds-008909.wav'],
#  ['sax_soprano', 'clarinet-medley_solos-17960.wav'],
#  ['clarinet', 'flute-medley_solos-10708.wav'],
#  ['cello', 'voice-irmas-1490.wav'],
#  ['voice', 'guitar_acoustic-irmas-3948.wav'],
#  ['flute', 'violin-medley_solos-19274.wav'],
#  ['voice', 'guitar_acoustic-irmas-4257.wav'],
#  ['flute', 'sax_alto-good_sounds-009446.wav'],
#  ['clarinet', 'sax_tenor-good_sounds-010216.wav'],
#  ['trumpet', 'flute-good_sounds-006682.wav'],
#  ['voice', 'cello-irmas-6372.wav'],
#  ['flute', 'oboe-good_sounds-008353.wav'],
#  ['violin', 'clarinet-medley_solos-9163.wav'],
#  ['cello', 'violin-irmas-4667.wav'],
#  ['cello', 'guitar_electric-medley_solos-14636.wav'],
#  ['cello', 'violin-medley_solos-1989.wav'],
#  ['violin', 'piano-medley_solos-7925.wav'],
#  ['voice', 'saxophone-irmas-2196.wav'],
#  ['clarinet', 'violin-good_sounds-016053.wav'],
#  ['sax_soprano', 'clarinet-good_sounds-002594.wav'],
#  ['trumpet', 'piano-medley_solos-11082.wav'],
#  ['piano', 'trumpet-irmas-1597.wav'],
#  ['bass', 'violin-irmas-4546.wav'],
#  ['piano', 'sax_soprano-good_sounds-011460.wav'],
#  ['violin', 'piano-irmas-479.wav'],
#  ['cello', 'flute-medley_solos-18976.wav'],
#  ['guitar_electric', 'saxophone-irmas-2259.wav'],
#  ['piano', 'guitar_acoustic-irmas-4077.wav'],
#  ['organ', 'piano-irmas-180.wav'],
#  ['clarinet', 'organ-irmas-3260.wav'],
#  ['violin', 'clarinet-medley_solos-17460.wav'],
#  ['organ', 'guitar_electric-irmas-5865.wav'],
#  ['piano', 'guitar_electric-medley_solos-11812.wav'],
#  ['guitar_electric', 'trumpet-irmas-1697.wav'],
#  ['sax_soprano', 'clarinet-good_sounds-002900.wav'],
#  ['violin', 'organ-irmas-3302.wav'],
#  ['sax_soprano', 'sax_alto-good_sounds-009718.wav'],
#  ['clarinet', 'sax_tenor-medley_solos-5844.wav'],
#  ['violin', 'voice-medley_solos-13654.wav'],
#  ['sax_tenor', 'cello-good_sounds-002198.wav'],
#  ['trumpet', 'sax_tenor-good_sounds-012513.wav'],
#  ['voice', 'flute-medley_solos-14602.wav'],
#  ['voice', 'violin-medley_solos-1067.wav'],
#  ['clarinet', 'flute-medley_solos-5292.wav'],
#  ['clarinet', 'flute-medley_solos-3988.wav'],
#  ['trumpet', 'violin-good_sounds-015625.wav'],
#  ['flute', 'clarinet-medley_solos-7603.wav'],
#  ['clarinet', 'piano-medley_solos-20537.wav'],
#  ['voice', 'flute-irmas-5410.wav'],
#  ['flute', 'clarinet-good_sounds-003974.wav'],
#  ['voice', 'clarinet-good_sounds-002383.wav'],
#  ['violin', 'guitar_acoustic-irmas-4030.wav'],
#  ['violin', 'clarinet-good_sounds-002393.wav'],
#  ['violin', 'voice-irmas-745.wav'],
#  ['sax_baritone', 'sax_tenor-good_sounds-012454.wav'],
#  ['clarinet', 'flute-good_sounds-005742.wav'],
#  ['sax_tenor', 'cello-good_sounds-002142.wav'],
#  ['guitar_electric', 'violin-irmas-5047.wav'],
#  ['violin', 'sax_soprano-good_sounds-011169.wav'],
#  ['clarinet', 'guitar_electric-medley_solos-6690.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-012142.wav'],
#  ['flute', 'piano-medley_solos-13568.wav'],
#  ['voice', 'guitar_electric-irmas-5821.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-010989.wav'],
#  ['guitar_electric', 'clarinet-good_sounds-004687.wav'],
#  ['clarinet', 'guitar_acoustic-irmas-4132.wav'],
#  ['flute', 'violin-irmas-5049.wav'],
#  ['voice', 'sax_tenor-medley_solos-21276.wav'],
#  ['guitar_electric', 'cello-irmas-6382.wav'],
#  ['trumpet', 'voice-irmas-760.wav'],
#  ['clarinet', 'oboe-good_sounds-008137.wav'],
#  ['organ', 'guitar_acoustic-irmas-4179.wav'],
#  ['voice', 'trumpet-irmas-1572.wav'],
#  ['flute', 'oboe-good_sounds-008368.wav'],
#  ['voice', 'saxophone-irmas-2221.wav'],
#  ['sax_tenor', 'sax_soprano-good_sounds-011251.wav'],
#  ['guitar_electric', 'guitar_acoustic-irmas-4465.wav'],
#  ['sax_alto', 'sax_soprano-good_sounds-011151.wav'],
#  ['flute', 'clarinet-good_sounds-003097.wav'],
#  ['violin', 'piano-medley_solos-13358.wav'],
#  ['voice', 'guitar_electric-irmas-5734.wav'],
#  ['sax_alto', 'sax_soprano-good_sounds-010973.wav'],
#  ['cello', 'voice-irmas-1448.wav'],
#  ['violin', 'trumpet-irmas-1604.wav'],
#  ['clarinet', 'flute-medley_solos-17624.wav'],
#  ['guitar_electric', 'violin-irmas-4660.wav'],
#  ['cello', 'saxophone-irmas-2403.wav'],
#  ['voice', 'sax_tenor-medley_solos-15406.wav'],
#  ['piano', 'guitar_acoustic-irmas-3929.wav'],
#  ['piano', 'guitar_electric-irmas-6105.wav'],
#  ['cello', 'guitar_acoustic-irmas-4509.wav'],
#  ['sax_soprano', 'violin-good_sounds-015161.wav'],
#  ['guitar_electric', 'cello-irmas-6328.wav'],
#  ['clarinet', 'piano-medley_solos-8357.wav'],
#  ['cello', 'saxophone-irmas-2618.wav'],
#  ['clarinet', 'guitar_acoustic-irmas-4095.wav'],
#  ['flute', 'sax_tenor-good_sounds-012395.wav'],
#  ['cello', 'guitar_electric-medley_solos-12991.wav'],
#  ['flute', 'violin-good_sounds-015935.wav'],
#  ['voice', 'trumpet-medley_solos-18298.wav'],
#  ['violin', 'saxophone-irmas-2187.wav'],
#  ['sax_tenor', 'saxophone-irmas-2231.wav'],
#  ['violin', 'voice-medley_solos-15744.wav'],
#  ['voice', 'sax_soprano-good_sounds-012139.wav'],
#  ['clarinet', 'piano-medley_solos-14420.wav'],
#  ['clarinet', 'flute-medley_solos-2647.wav'],
#  ['flute', 'cello-irmas-6353.wav'],
#  ['clarinet', 'bass-good_sounds-000031.wav'],
#  ['piano', 'violin-irmas-4923.wav'],
#  ['cello', 'trumpet-irmas-2063.wav'],
#  ['flute', 'clarinet-good_sounds-002929.wav'],
#  ['sax_baritone', 'sax_soprano-good_sounds-012190.wav'],
#  ['cello', 'flute-medley_solos-20207.wav'],
#  ['clarinet', 'violin-medley_solos-3218.wav'],
#  ['violin', 'guitar_acoustic-irmas-4442.wav'],
#  ['trumpet', 'violin-irmas-4816.wav'],
#  ['flute', 'organ-irmas-3297.wav'],
#  ['clarinet', 'flute-medley_solos-9421.wav'],
#  ['trumpet', 'violin-good_sounds-015603.wav'],
#  ['cello', 'clarinet-irmas-3849.wav'],
#  ['sax_baritone', 'trumpet-good_sounds-012769.wav'],
#  ['guitar_electric', 'guitar_acoustic-irmas-4211.wav'],
#  ['organ', 'flute-irmas-5338.wav'],
#  ['violin', 'cello-irmas-6591.wav'],
#  ['voice', 'guitar_electric-irmas-6277.wav'],
#  ['organ', 'voice-irmas-795.wav'],
#  ['sax_tenor', 'sax_soprano-good_sounds-011738.wav'],
#  ['flute', 'violin-medley_solos-10073.wav'],
#  ['cello', 'sax_tenor-good_sounds-012485.wav'],
#  ['piano', 'clarinet-irmas-3689.wav'],
#  ['cello', 'guitar_acoustic-irmas-4104.wav'],
#  ['organ', 'clarinet-irmas-3450.wav'],
#  ['guitar_electric', 'cello-irmas-6531.wav'],
#  ['piano', 'flute-medley_solos-5518.wav'],
#  ['trumpet', 'flute-good_sounds-006851.wav'],
#  ['sax_soprano', 'cello-good_sounds-002193.wav'],
#  ['flute', 'trumpet-medley_solos-20433.wav'],
#  ['violin', 'piano-medley_solos-14426.wav'],
#  ['organ', 'voice-irmas-722.wav'],
#  ['violin', 'clarinet-medley_solos-15851.wav'],
#  ['cello', 'saxophone-irmas-2090.wav'],
#  ['voice', 'saxophone-irmas-2189.wav'],
#  ['cello', 'organ-irmas-3230.wav'],
#  ['organ', 'violin-irmas-4887.wav'],
#  ['guitar_electric', 'violin-irmas-4710.wav'],
#  ['clarinet', 'guitar_acoustic-irmas-3908.wav'],
#  ['guitar_electric', 'organ-irmas-3362.wav'],
#  ['sax_soprano', 'voice-medley_solos-2419.wav'],
#  ['voice', 'saxophone-irmas-2224.wav'],
#  ['sax_tenor', 'saxophone-irmas-2124.wav'],
#  ['violin', 'cello-good_sounds-001653.wav'],
#  ['sax_baritone', 'cello-good_sounds-001268.wav'],
#  ['guitar_electric', 'voice-irmas-844.wav'],
#  ['clarinet', 'violin-good_sounds-015968.wav'],
#  ['clarinet', 'cello-good_sounds-001273.wav'],
#  ['violin', 'piccolo-good_sounds-008821.wav'],
#  ['clarinet', 'flute-good_sounds-007688.wav'],
#  ['voice', 'piano-irmas-690.wav'],
#  ['trumpet', 'flute-irmas-5238.wav'],
#  ['organ', 'trumpet-irmas-1574.wav'],
#  ['voice', 'trumpet-irmas-1644.wav'],
#  ['guitar_electric', 'saxophone-irmas-2321.wav'],
#  ['organ', 'saxophone-irmas-2236.wav'],
#  ['flute', 'clarinet-medley_solos-3313.wav'],
#  ['flute', 'piccolo-good_sounds-008682.wav'],
#  ['cello', 'saxophone-irmas-2250.wav'],
#  ['clarinet', 'trumpet-good_sounds-013189.wav'],
#  ['cello', 'voice-irmas-850.wav'],
#  ['sax_tenor', 'sax_soprano-good_sounds-011205.wav'],
#  ['cello', 'clarinet-irmas-3762.wav'],
#  ['trumpet', 'voice-medley_solos-1665.wav'],
#  ['cello', 'voice-irmas-1320.wav'],
#  ['voice', 'trumpet-irmas-1828.wav'],
#  ['guitar_electric', 'clarinet-irmas-3662.wav'],
#  ['violin', 'sax_alto-good_sounds-009410.wav'],
#  ['organ', 'voice-irmas-1306.wav'],
#  ['flute', 'clarinet-medley_solos-15268.wav'],
#  ['clarinet', 'piano-irmas-712.wav'],
#  ['cello', 'sax_baritone-good_sounds-010519.wav'],
#  ['piano', 'saxophone-irmas-2688.wav'],
#  ['sax_soprano', 'voice-medley_solos-294.wav'],
#  ['flute', 'violin-medley_solos-13257.wav'],
#  ['flute', 'violin-good_sounds-015601.wav'],
#  ['violin', 'guitar_electric-medley_solos-11809.wav'],
#  ['sax_baritone', 'sax_soprano-good_sounds-011875.wav'],
#  ['flute', 'clarinet-medley_solos-13454.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011375.wav'],
#  ['voice', 'violin-irmas-5015.wav'],
#  ['violin', 'flute-irmas-5301.wav'],
#  ['piano', 'guitar_electric-medley_solos-898.wav'],
#  ['piano', 'guitar_acoustic-irmas-4349.wav'],
#  ['violin', 'guitar_acoustic-irmas-4196.wav'],
#  ['cello', 'trumpet-irmas-1693.wav'],
#  ['cello', 'guitar_acoustic-irmas-3904.wav'],
#  ['voice', 'flute-irmas-5146.wav'],
#  ['violin', 'flute-good_sounds-005759.wav'],
#  ['clarinet', 'oboe-good_sounds-008133.wav'],
#  ['guitar_electric', 'guitar_acoustic-irmas-4005.wav'],
#  ['flute', 'clarinet-good_sounds-003235.wav'],
#  ['bass', 'clarinet-medley_solos-9986.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011033.wav'],
#  ['violin', 'guitar_electric-medley_solos-9811.wav'],
#  ['sax_alto', 'sax_soprano-good_sounds-011480.wav'],
#  ['clarinet', 'sax_tenor-good_sounds-010241.wav'],
#  ['organ', 'trumpet-irmas-1513.wav'],
#  ['flute', 'clarinet-medley_solos-11169.wav'],
#  ['sax_baritone', 'violin-good_sounds-015700.wav'],
#  ['guitar_electric', 'cello-irmas-6504.wav'],
#  ['organ', 'voice-irmas-1429.wav'],
#  ['flute', 'saxophone-irmas-2136.wav'],
#  ['piano', 'sax_baritone-good_sounds-010643.wav'],
#  ['flute', 'piano-medley_solos-12161.wav'],
#  ['organ', 'violin-irmas-4905.wav'],
#  ['piano', 'guitar_electric-medley_solos-12103.wav'],
#  ['voice', 'guitar_electric-irmas-6211.wav'],
#  ['guitar_electric', 'voice-irmas-809.wav'],
#  ['flute', 'piccolo-good_sounds-008925.wav'],
#  ['clarinet', 'flute-medley_solos-5550.wav'],
#  ['clarinet', 'violin-medley_solos-7519.wav'],
#  ['organ', 'clarinet-irmas-3397.wav'],
#  ['violin', 'trumpet-irmas-1937.wav'],
#  ['cello', 'flute-irmas-5249.wav'],
#  ['piano', 'guitar_acoustic-irmas-4173.wav'],
#  ['violin', 'organ-irmas-3337.wav'],
#  ['sax_baritone', 'sax_soprano-good_sounds-011739.wav'],
#  ['violin', 'organ-irmas-2791.wav'],
#  ['clarinet', 'violin-medley_solos-15277.wav'],
#  ['violin', 'voice-irmas-907.wav'],
#  ['organ', 'guitar_electric-irmas-5840.wav'],
#  ['cello', 'organ-irmas-3087.wav'],
#  ['flute', 'piano-medley_solos-109.wav'],
#  ['piano', 'guitar_electric-irmas-6106.wav'],
#  ['cello', 'violin-medley_solos-2919.wav'],
#  ['flute', 'trumpet-irmas-1980.wav'],
#  ['bass', 'voice-medley_solos-3066.wav'],
#  ['clarinet', 'trumpet-good_sounds-013196.wav'],
#  ['violin', 'clarinet-medley_solos-15903.wav'],
#  ['organ', 'trumpet-irmas-1846.wav'],
#  ['piano', 'trumpet-irmas-1600.wav'],
#  ['organ', 'violin-irmas-4867.wav'],
#  ['flute', 'organ-irmas-2896.wav'],
#  ['violin', 'clarinet-irmas-3703.wav'],
#  ['organ', 'guitar_electric-irmas-5719.wav'],
#  ['voice', 'guitar_acoustic-irmas-4276.wav'],
#  ['piano', 'saxophone-irmas-2591.wav'],
#  ['trumpet', 'piano-irmas-595.wav'],
#  ['organ', 'flute-irmas-5484.wav'],
#  ['cello', 'saxophone-irmas-2287.wav'],
#  ['cello', 'piano-medley_solos-8796.wav'],
#  ['flute', 'trumpet-irmas-1988.wav'],
#  ['sax_tenor', 'trumpet-good_sounds-013924.wav'],
#  ['organ', 'piano-irmas-614.wav'],
#  ['piano', 'trumpet-good_sounds-013156.wav'],
#  ['trumpet', 'flute-good_sounds-007128.wav'],
#  ['sax_baritone', 'cello-good_sounds-002129.wav'],
#  ['voice', 'saxophone-irmas-2364.wav'],
#  ['voice', 'guitar_electric-irmas-5952.wav'],
#  ['flute', 'violin-good_sounds-016331.wav'],
#  ['piano', 'clarinet-irmas-3576.wav'],
#  ['clarinet', 'flute-good_sounds-007620.wav'],
#  ['trumpet', 'oboe-good_sounds-008220.wav'],
#  ['voice', 'flute-irmas-5123.wav'],
#  ['piano', 'guitar_acoustic-irmas-4263.wav'],
#  ['flute', 'violin-good_sounds-016536.wav'],
#  ['voice', 'guitar_acoustic-irmas-3930.wav'],
#  ['flute', 'sax_soprano-good_sounds-011250.wav'],
#  ['sax_soprano', 'saxophone-irmas-2220.wav'],
#  ['guitar_electric', 'violin-medley_solos-21528.wav'],
#  ['flute', 'clarinet-irmas-3600.wav'],
#  ['violin', 'flute-irmas-5496.wav'],
#  ['flute', 'violin-medley_solos-7674.wav'],
#  ['voice', 'guitar_electric-medley_solos-19243.wav'],
#  ['cello', 'bass-good_sounds-000040.wav'],
#  ['piano', 'clarinet-irmas-3481.wav'],
#  ['flute', 'piano-medley_solos-19193.wav'],
#  ['cello', 'flute-medley_solos-8807.wav'],
#  ['piano', 'violin-irmas-4689.wav'],
#  ['cello', 'flute-irmas-5475.wav'],
#  ['trumpet', 'flute-good_sounds-006485.wav'],
#  ['flute', 'trumpet-good_sounds-013018.wav'],
#  ['violin', 'voice-irmas-1027.wav'],
#  ['guitar_electric', 'voice-irmas-723.wav'],
#  ['guitar_acoustic', 'voice-irmas-1281.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011702.wav'],
#  ['sax_alto', 'sax_soprano-good_sounds-011412.wav'],
#  ['guitar_electric', 'clarinet-irmas-3717.wav'],
#  ['sax_soprano', 'sax_tenor-good_sounds-012282.wav'],
#  ['violin', 'sax_alto-good_sounds-009825.wav'],
#  ['cello', 'bass-good_sounds-000026.wav'],
#  ['voice', 'saxophone-irmas-2432.wav'],
#  ['violin', 'flute-irmas-5491.wav'],
#  ['clarinet', 'guitar_acoustic-irmas-3942.wav'],
#  ['violin', 'sax_tenor-medley_solos-2015.wav'],
#  ['voice', 'piano-irmas-282.wav'],
#  ['piano', 'trumpet-irmas-1916.wav'],
#  ['piano', 'flute-irmas-5401.wav'],
#  ['violin', 'sax_tenor-medley_solos-16404.wav'],
#  ['sax_tenor', 'violin-irmas-4754.wav'],
#  ['sax_soprano', 'sax_alto-good_sounds-009771.wav'],
#  ['clarinet', 'sax_tenor-good_sounds-010201.wav'],
#  ['piano', 'flute-irmas-5255.wav'],
#  ['flute', 'sax_soprano-good_sounds-011318.wav'],
#  ['sax_soprano', 'sax_alto-good_sounds-010151.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011376.wav'],
#  ['voice', 'violin-irmas-4578.wav'],
#  ['guitar_electric', 'guitar_acoustic-irmas-4029.wav'],
#  ['cello', 'flute-irmas-5259.wav'],
#  ['piano', 'guitar_electric-medley_solos-9813.wav'],
#  ['voice', 'guitar_electric-medley_solos-9933.wav'],
#  ['clarinet', 'flute-good_sounds-007757.wav'],
#  ['guitar_electric', 'voice-irmas-1091.wav'],
#  ['flute', 'sax_tenor-good_sounds-012446.wav'],
#  ['piano', 'clarinet-irmas-3644.wav'],
#  ['cello', 'piano-medley_solos-20995.wav'],
#  ['clarinet', 'violin-good_sounds-016035.wav'],
#  ['violin', 'flute-good_sounds-006779.wav'],
#  ['guitar_electric', 'clarinet-irmas-3687.wav'],
#  ['clarinet', 'sax_alto-good_sounds-009420.wav'],
#  ['piano', 'saxophone-irmas-2222.wav'],
#  ['guitar_electric', 'voice-irmas-766.wav'],
#  ['voice', 'organ-irmas-3153.wav'],
#  ['sax_alto', 'sax_soprano-good_sounds-011559.wav'],
#  ['cello', 'flute-irmas-5324.wav'],
#  ['guitar_electric', 'violin-irmas-4602.wav'],
#  ['trumpet', 'sax_baritone-good_sounds-010641.wav'],
#  ['piano', 'saxophone-irmas-2620.wav'],
#  ['clarinet', 'flute-medley_solos-13323.wav'],
#  ['flute', 'sax_alto-good_sounds-009673.wav'],
#  ['voice', 'trumpet-irmas-1811.wav'],
#  ['sax_soprano', 'violin-medley_solos-12630.wav'],
#  ['guitar_electric', 'saxophone-irmas-2470.wav'],
#  ['cello', 'clarinet-good_sounds-003732.wav'],
#  ['sax_alto', 'sax_soprano-good_sounds-010980.wav'],
#  ['cello', 'flute-medley_solos-18194.wav'],
#  ['guitar_electric', 'cello-irmas-6567.wav'],
#  ['sax_soprano', 'sax_alto-good_sounds-009544.wav'],
#  ['cello', 'organ-irmas-2840.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011149.wav'],
#  ['cello', 'trumpet-irmas-1609.wav'],
#  ['clarinet', 'voice-medley_solos-6373.wav'],
#  ['clarinet', 'flute-medley_solos-15292.wav'],
#  ['flute', 'violin-medley_solos-3033.wav'],
#  ['violin', 'flute-irmas-5201.wav'],
#  ['sax_tenor', 'sax_alto-good_sounds-009817.wav'],
#  ['trumpet', 'flute-good_sounds-007475.wav'],
#  ['piano', 'clarinet-medley_solos-8231.wav'],
#  ['violin', 'trumpet-irmas-1876.wav'],
#  ['guitar_acoustic', 'voice-irmas-1326.wav'],
#  ['voice', 'saxophone-irmas-2214.wav'],
#  ['trumpet', 'oboe-good_sounds-008513.wav'],
#  ['voice', 'guitar_electric-irmas-5918.wav'],
#  ['flute', 'cello-good_sounds-000419.wav'],
#  ['clarinet', 'guitar_electric-irmas-6016.wav'],
#  ['violin', 'guitar_electric-irmas-5608.wav'],
#  ['cello', 'sax_tenor-good_sounds-012588.wav'],
#  ['trumpet', 'sax_tenor-medley_solos-10658.wav'],
#  ['guitar_electric', 'guitar_acoustic-irmas-4256.wav'],
#  ['voice', 'guitar_electric-irmas-5576.wav'],
#  ['flute', 'sax_baritone-good_sounds-010535.wav'],
#  ['clarinet', 'flute-medley_solos-12663.wav'],
#  ['violin', 'organ-irmas-2733.wav'],
#  ['guitar_electric', 'trumpet-irmas-1983.wav'],
#  ['voice', 'guitar_acoustic-irmas-4001.wav'],
#  ['cello', 'clarinet-irmas-3495.wav'],
#  ['clarinet', 'oboe-good_sounds-008235.wav'],
#  ['sax_baritone', 'trumpet-good_sounds-013569.wav'],
#  ['voice', 'guitar_acoustic-irmas-4252.wav'],
#  ['violin', 'guitar_electric-irmas-5879.wav'],
#  ['trumpet', 'flute-irmas-5336.wav'],
#  ['flute', 'guitar_electric-irmas-5742.wav'],
#  ['trumpet', 'organ-irmas-3277.wav'],
#  ['guitar_electric', 'trumpet-irmas-1890.wav'],
#  ['guitar_electric', 'voice-irmas-1092.wav'],
#  ['sax_tenor', 'cello-good_sounds-002189.wav'],
#  ['guitar_electric', 'voice-irmas-1277.wav'],
#  ['sax_soprano', 'voice-medley_solos-1638.wav'],
#  ['guitar_electric', 'saxophone-irmas-2402.wav'],
#  ['guitar_electric', 'piano-irmas-72.wav'],
#  ['violin', 'flute-irmas-5537.wav'],
#  ['violin', 'trumpet-medley_solos-3148.wav'],
#  ['sax_tenor', 'sax_alto-good_sounds-009672.wav'],
#  ['sax_tenor', 'cello-good_sounds-002017.wav'],
#  ['piano', 'clarinet-irmas-3829.wav'],
#  ['flute', 'clarinet-medley_solos-20524.wav'],
#  ['flute', 'clarinet-medley_solos-2320.wav'],
#  ['sax_alto', 'sax_soprano-good_sounds-011464.wav'],
#  ['guitar_electric', 'violin-irmas-4914.wav'],
#  ['cello', 'flute-good_sounds-006428.wav'],
#  ['clarinet', 'flute-medley_solos-10925.wav'],
#  ['clarinet', 'flute-irmas-5256.wav'],
#  ['voice', 'saxophone-irmas-2323.wav'],
#  ['voice', 'flute-irmas-5440.wav'],
#  ['organ', 'voice-irmas-841.wav'],
#  ['voice', 'guitar_electric-irmas-6099.wav'],
#  ['cello', 'violin-irmas-4722.wav'],
#  ['clarinet', 'piccolo-good_sounds-008878.wav'],
#  ['violin', 'flute-irmas-5467.wav'],
#  ['guitar_electric', 'trumpet-irmas-1516.wav'],
#  ['guitar_electric', 'violin-irmas-5048.wav'],
#  ['clarinet', 'piano-medley_solos-19696.wav'],
#  ['clarinet', 'piano-medley_solos-19730.wav'],
#  ['guitar_electric', 'organ-irmas-2860.wav'],
#  ['flute', 'voice-medley_solos-15682.wav'],
#  ['cello', 'guitar_electric-irmas-6238.wav'],
#  ['voice', 'flute-irmas-5522.wav'],
#  ['guitar_electric', 'saxophone-irmas-2304.wav'],
#  ['organ', 'piano-irmas-176.wav'],
#  ['guitar_electric', 'saxophone-irmas-2116.wav'],
#  ['organ', 'violin-irmas-4742.wav'],
#  ['cello', 'flute-good_sounds-006199.wav'],
#  ['flute', 'violin-good_sounds-016403.wav'],
#  ['organ', 'flute-irmas-5167.wav'],
#  ['guitar_electric', 'saxophone-irmas-2415.wav'],
#  ['trumpet', 'sax_tenor-good_sounds-012518.wav'],
#  ['clarinet', 'flute-medley_solos-9850.wav'],
#  ['cello', 'clarinet-irmas-3852.wav'],
#  ['voice', 'piano-irmas-332.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011427.wav'],
#  ['cello', 'bass-good_sounds-000053.wav'],
#  ['piano', 'guitar_electric-irmas-5765.wav'],
#  ['guitar_electric', 'violin-good_sounds-015835.wav'],
#  ['piano', 'sax_tenor-good_sounds-012507.wav'],
#  ['cello', 'guitar_acoustic-irmas-3914.wav'],
#  ['clarinet', 'flute-good_sounds-007463.wav'],
#  ['voice', 'violin-irmas-4691.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011690.wav'],
#  ['clarinet', 'sax_baritone-good_sounds-010662.wav'],
#  ['violin', 'clarinet-good_sounds-002779.wav'],
#  ['cello', 'violin-medley_solos-17033.wav'],
#  ['guitar_electric', 'voice-irmas-761.wav'],
#  ['guitar_electric', 'voice-irmas-1247.wav'],
#  ['violin', 'sax_tenor-medley_solos-18179.wav'],
#  ['guitar_acoustic', 'saxophone-irmas-2292.wav'],
#  ['cello', 'clarinet-irmas-3804.wav'],
#  ['sax_baritone', 'sax_soprano-good_sounds-011367.wav'],
#  ['cello', 'guitar_acoustic-irmas-4431.wav'],
#  ['violin', 'guitar_electric-medley_solos-13652.wav'],
#  ['voice', 'guitar_acoustic-irmas-4428.wav'],
#  ['clarinet', 'trumpet-medley_solos-19332.wav'],
#  ['flute', 'bass-good_sounds-000153.wav'],
#  ['piano', 'guitar_electric-irmas-5881.wav'],
#  ['sax_baritone', 'sax_soprano-good_sounds-011496.wav'],
#  ['flute', 'trumpet-irmas-1928.wav'],
#  ['guitar_electric', 'voice-irmas-1144.wav'],
#  ['violin', 'voice-medley_solos-1814.wav'],
#  ['guitar_electric', 'saxophone-irmas-2613.wav'],
#  ['violin', 'guitar_electric-medley_solos-16126.wav'],
#  ['cello', 'violin-good_sounds-015054.wav'],
#  ['clarinet', 'guitar_acoustic-irmas-4322.wav'],
#  ['flute', 'cello-good_sounds-001453.wav'],
#  ['piano', 'guitar_electric-irmas-6285.wav'],
#  ['cello', 'flute-medley_solos-16693.wav'],
#  ['sax_soprano', 'sax_alto-good_sounds-009702.wav'],
#  ['violin', 'saxophone-irmas-2622.wav'],
#  ['piano', 'flute-medley_solos-11807.wav'],
#  ['cello', 'guitar_acoustic-irmas-4194.wav'],
#  ['trumpet', 'clarinet-medley_solos-8759.wav'],
#  ['organ', 'cello-irmas-6319.wav'],
#  ['piano', 'guitar_electric-irmas-6279.wav'],
#  ['flute', 'piano-medley_solos-12011.wav'],
#  ['clarinet', 'piano-irmas-478.wav'],
#  ['flute', 'organ-irmas-3050.wav'],
#  ['flute', 'sax_baritone-good_sounds-010802.wav'],
#  ['clarinet', 'sax_alto-good_sounds-009419.wav'],
#  ['voice', 'flute-irmas-5383.wav'],
#  ['piano', 'guitar_acoustic-irmas-4246.wav'],
#  ['flute', 'clarinet-good_sounds-004008.wav'],
#  ['violin', 'clarinet-good_sounds-003052.wav'],
#  ['sax_tenor', 'piccolo-good_sounds-009315.wav'],
#  ['flute', 'violin-medley_solos-13418.wav'],
#  ['clarinet', 'trumpet-good_sounds-012784.wav'],
#  ['flute', 'clarinet-medley_solos-4017.wav'],
#  ['sax_tenor', 'sax_soprano-good_sounds-011136.wav'],
#  ['voice', 'saxophone-irmas-2639.wav'],
#  ['flute', 'clarinet-medley_solos-5921.wav'],
#  ['guitar_electric', 'voice-irmas-892.wav'],
#  ['oboe', 'sax_soprano-good_sounds-012085.wav'],
#  ['clarinet', 'violin-irmas-4893.wav'],
#  ['organ', 'guitar_acoustic-irmas-4440.wav'],
#  ['voice', 'guitar_acoustic-irmas-3987.wav'],
#  ['organ', 'guitar_acoustic-irmas-3923.wav'],
#  ['guitar_electric', 'voice-irmas-1224.wav'],
#  ['flute', 'violin-medley_solos-7917.wav'],
#  ['voice', 'guitar_electric-irmas-6304.wav'],
#  ['cello', 'guitar_acoustic-irmas-4116.wav'],
#  ['cello', 'guitar_acoustic-irmas-4026.wav'],
#  ['clarinet', 'violin-medley_solos-8244.wav'],
#  ['cello', 'organ-irmas-2983.wav'],
#  ['clarinet', 'flute-medley_solos-8187.wav'],
#  ['guitar_electric', 'voice-irmas-1198.wav'],
#  ['violin', 'clarinet-irmas-3692.wav'],
#  ['cello', 'violin-irmas-4599.wav'],
#  ['sax_soprano', 'sax_alto-good_sounds-009652.wav'],
#  ['trumpet', 'voice-medley_solos-18137.wav'],
#  ['sax_alto', 'sax_soprano-good_sounds-011545.wav'],
#  ['flute', 'violin-good_sounds-015279.wav'],
#  ['guitar_electric', 'organ-irmas-3372.wav'],
#  ['clarinet', 'sax_tenor-medley_solos-11509.wav'],
#  ['cello', 'flute-medley_solos-13851.wav'],
#  ['violin', 'cello-irmas-6523.wav'],
#  ['flute', 'guitar_acoustic-irmas-3991.wav'],
#  ['flute', 'clarinet-medley_solos-16519.wav'],
#  ['violin', 'guitar_electric-irmas-5581.wav'],
#  ['violin', 'piano-medley_solos-7042.wav'],
#  ['organ', 'cello-irmas-6581.wav'],
#  ['cello', 'sax_tenor-good_sounds-012551.wav'],
#  ['violin', 'clarinet-irmas-3889.wav'],
#  ['clarinet', 'trumpet-good_sounds-013814.wav'],
#  ['flute', 'trumpet-good_sounds-013089.wav'],
#  ['flute', 'piano-irmas-28.wav'],
#  ['trumpet', 'clarinet-good_sounds-003451.wav'],
#  ['cello', 'violin-medley_solos-2518.wav'],
#  ['sax_tenor', 'clarinet-good_sounds-002826.wav'],
#  ['sax_soprano', 'flute-good_sounds-007127.wav'],
#  ['piano', 'guitar_acoustic-irmas-4346.wav'],
#  ['cello', 'piano-irmas-142.wav'],
#  ['organ', 'guitar_electric-irmas-5582.wav'],
#  ['flute', 'piano-medley_solos-6222.wav'],
#  ['voice', 'flute-irmas-5277.wav'],
#  ['sax_soprano', 'oboe-good_sounds-008601.wav'],
#  ['piano', 'guitar_electric-irmas-6189.wav'],
#  ['violin', 'guitar_electric-medley_solos-2821.wav'],
#  ['cello', 'guitar_electric-medley_solos-1809.wav'],
#  ['organ', 'violin-irmas-4981.wav'],
#  ['flute', 'oboe-good_sounds-008151.wav'],
#  ['sax_soprano', 'piccolo-good_sounds-008847.wav'],
#  ['sax_soprano', 'clarinet-good_sounds-004267.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011122.wav'],
#  ['piano', 'guitar_electric-irmas-5941.wav'],
#  ['cello', 'guitar_electric-irmas-6230.wav'],
#  ['violin', 'sax_tenor-medley_solos-1358.wav'],
#  ['cello', 'saxophone-irmas-2320.wav'],
#  ['cello', 'organ-irmas-3025.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011570.wav'],
#  ['voice', 'flute-irmas-5385.wav'],
#  ['guitar_electric', 'piano-irmas-24.wav'],
#  ['voice', 'flute-medley_solos-10228.wav'],
#  ['flute', 'sax_baritone-good_sounds-010672.wav'],
#  ['clarinet', 'trumpet-good_sounds-013380.wav'],
#  ['flute', 'violin-good_sounds-016371.wav'],
#  ['guitar_electric', 'saxophone-irmas-2107.wav'],
#  ['clarinet', 'violin-good_sounds-015621.wav'],
#  ['voice', 'guitar_acoustic-irmas-3918.wav'],
#  ['voice', 'violin-irmas-4577.wav'],
#  ['violin', 'sax_tenor-medley_solos-18776.wav'],
#  ['piano', 'trumpet-irmas-1990.wav'],
#  ['flute', 'violin-good_sounds-016556.wav'],
#  ['clarinet', 'trumpet-irmas-1951.wav'],
#  ['clarinet', 'flute-medley_solos-2705.wav'],
#  ['violin', 'piano-medley_solos-13344.wav'],
#  ['flute', 'clarinet-medley_solos-2585.wav'],
#  ['guitar_electric', 'piano-irmas-684.wav'],
#  ['voice', 'violin-irmas-4990.wav'],
#  ['cello', 'clarinet-medley_solos-5011.wav'],
#  ['clarinet', 'organ-irmas-2929.wav'],
#  ['trumpet', 'clarinet-good_sounds-002316.wav'],
#  ['clarinet', 'trumpet-irmas-1641.wav'],
#  ['violin', 'clarinet-medley_solos-10773.wav'],
#  ['organ', 'guitar_electric-irmas-6278.wav'],
#  ['flute', 'violin-good_sounds-016145.wav'],
#  ['piano', 'clarinet-irmas-3676.wav'],
#  ['piano', 'flute-medley_solos-14594.wav'],
#  ['clarinet', 'saxophone-irmas-2143.wav'],
#  ['piano', 'saxophone-irmas-2360.wav'],
#  ['piano', 'clarinet-irmas-3636.wav'],
#  ['bass', 'piano-medley_solos-11138.wav'],
#  ['violin', 'piano-irmas-466.wav'],
#  ['cello', 'bass-good_sounds-000133.wav'],
#  ['piano', 'bass-good_sounds-000143.wav'],
#  ['organ', 'flute-irmas-5231.wav'],
#  ['trumpet', 'flute-medley_solos-7927.wav'],
#  ['flute', 'piano-medley_solos-16254.wav'],
#  ['flute', 'piano-medley_solos-15906.wav'],
#  ['trumpet', 'violin-good_sounds-015618.wav'],
#  ['clarinet', 'organ-irmas-3097.wav'],
#  ['voice', 'guitar_electric-irmas-5736.wav'],
#  ['voice', 'trumpet-irmas-1961.wav'],
#  ['clarinet', 'guitar_acoustic-irmas-4370.wav'],
#  ['piano', 'flute-medley_solos-5686.wav'],
#  ['guitar_electric', 'organ-irmas-3317.wav'],
#  ['piano', 'trumpet-irmas-1967.wav'],
#  ['clarinet', 'trumpet-good_sounds-013537.wav'],
#  ['flute', 'piano-medley_solos-10713.wav'],
#  ['piano', 'saxophone-irmas-2215.wav'],
#  ['flute', 'clarinet-medley_solos-2255.wav'],
#  ['sax_baritone', 'sax_tenor-good_sounds-012333.wav'],
#  ['guitar_electric', 'violin-irmas-4613.wav'],
#  ['violin', 'piano-irmas-442.wav'],
#  ['sax_soprano', 'violin-good_sounds-015244.wav'],
#  ['guitar_electric', 'trumpet-irmas-1837.wav'],
#  ['trumpet', 'flute-medley_solos-19222.wav'],
#  ['organ', 'voice-irmas-748.wav'],
#  ['clarinet', 'flute-medley_solos-12307.wav'],
#  ['trumpet', 'flute-good_sounds-006689.wav'],
#  ['violin', 'clarinet-medley_solos-20958.wav'],
#  ['clarinet', 'sax_alto-good_sounds-009402.wav'],
#  ['voice', 'guitar_electric-irmas-5852.wav'],
#  ['violin', 'voice-medley_solos-20939.wav'],
#  ['sax_soprano', 'sax_tenor-good_sounds-012424.wav'],
#  ['guitar_electric', 'organ-irmas-3193.wav'],
#  ['guitar_electric', 'organ-irmas-3248.wav'],
#  ['flute', 'clarinet-good_sounds-003595.wav'],
#  ['clarinet', 'violin-medley_solos-8040.wav'],
#  ['clarinet', 'piano-medley_solos-11861.wav'],
#  ['cello', 'guitar_acoustic-irmas-3922.wav'],
#  ['guitar_electric', 'guitar_acoustic-irmas-4290.wav'],
#  ['oboe', 'flute-medley_solos-13672.wav'],
#  ['trumpet', 'saxophone-irmas-2367.wav'],
#  ['guitar_electric', 'clarinet-irmas-3882.wav'],
#  ['piano', 'guitar_acoustic-irmas-4443.wav'],
#  ['flute', 'violin-medley_solos-15320.wav'],
#  ['flute', 'voice-medley_solos-688.wav'],
#  ['flute', 'violin-good_sounds-016420.wav'],
#  ['guitar_electric', 'voice-irmas-1065.wav'],
#  ['piano', 'sax_baritone-good_sounds-010395.wav'],
#  ['guitar_electric', 'violin-irmas-4888.wav'],
#  ['clarinet', 'cello-good_sounds-001235.wav'],
#  ['violin', 'saxophone-irmas-2186.wav'],
#  ['cello', 'sax_tenor-good_sounds-012653.wav'],
#  ['clarinet', 'guitar_electric-medley_solos-5399.wav'],
#  ['cello', 'guitar_acoustic-irmas-4149.wav'],
#  ['organ', 'voice-irmas-1272.wav'],
#  ['sax_baritone', 'sax_tenor-medley_solos-15404.wav'],
#  ['cello', 'violin-good_sounds-015918.wav'],
#  ['guitar_acoustic', 'guitar_electric-irmas-6252.wav'],
#  ['trumpet', 'sax_soprano-good_sounds-011890.wav'],
#  ['violin', 'cello-irmas-6528.wav'],
#  ['guitar_electric', 'voice-irmas-927.wav'],
#  ['clarinet', 'trumpet-good_sounds-013533.wav'],
#  ['trumpet', 'flute-good_sounds-006454.wav'],
#  ['clarinet', 'flute-medley_solos-9735.wav'],
#  ['flute', 'clarinet-medley_solos-8316.wav'],
#  ['violin', 'clarinet-irmas-3760.wav'],
#  ['guitar_electric', 'organ-irmas-2831.wav'],
#  ['flute', 'sax_soprano-good_sounds-011266.wav'],
#  ['voice', 'saxophone-irmas-2699.wav'],
#  ['flute', 'clarinet-good_sounds-003778.wav'],
#  ['piano', 'flute-irmas-5495.wav'],
#  ['flute', 'clarinet-good_sounds-004126.wav'],
#  ['organ', 'voice-irmas-824.wav'],
#  ['flute', 'piano-medley_solos-15450.wav'],
#  ['guitar_electric', 'piano-irmas-456.wav'],
#  ['trumpet', 'clarinet-good_sounds-003514.wav'],
#  ['organ', 'voice-irmas-920.wav'],
#  ['cello', 'guitar_acoustic-irmas-4271.wav'],
#  ['clarinet', 'trumpet-good_sounds-014204.wav'],
#  ['guitar_electric', 'saxophone-irmas-2554.wav'],
#  ['trumpet', 'clarinet-irmas-3554.wav'],
#  ['flute', 'clarinet-medley_solos-21278.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011613.wav'],
#  ['violin', 'flute-medley_solos-20637.wav'],
#  ['sax_tenor', 'sax_soprano-good_sounds-011174.wav'],
#  ['cello', 'flute-irmas-5260.wav'],
#  ['organ', 'voice-irmas-1436.wav'],
#  ['cello', 'violin-medley_solos-20355.wav'],
#  ['flute', 'clarinet-good_sounds-002531.wav'],
#  ['clarinet', 'flute-good_sounds-005974.wav'],
#  ['violin', 'voice-irmas-1240.wav'],
#  ['cello', 'voice-irmas-827.wav'],
#  ['guitar_electric', 'trumpet-irmas-1830.wav'],
#  ['sax_alto', 'sax_soprano-good_sounds-011225.wav'],
#  ['sax_soprano', 'clarinet-good_sounds-002763.wav'],
#  ['guitar_electric', 'guitar_acoustic-irmas-4175.wav'],
#  ['piano', 'violin-medley_solos-18638.wav'],
#  ['voice', 'trumpet-irmas-1682.wav'],
#  ['violin', 'cello-good_sounds-002294.wav'],
#  ['cello', 'piano-irmas-662.wav'],
#  ['violin', 'saxophone-irmas-2180.wav'],
#  ['piano', 'trumpet-irmas-1915.wav'],
#  ['piano', 'flute-irmas-5507.wav'],
#  ['piano', 'flute-medley_solos-13788.wav'],
#  ['guitar_electric', 'cello-irmas-6514.wav'],
#  ['trumpet', 'violin-good_sounds-016195.wav'],
#  ['trumpet', 'guitar_electric-medley_solos-11489.wav'],
#  ['violin', 'flute-good_sounds-006977.wav'],
#  ['violin', 'cello-good_sounds-001606.wav'],
#  ['trumpet', 'sax_soprano-good_sounds-011544.wav'],
#  ['clarinet', 'flute-good_sounds-007518.wav'],
#  ['cello', 'piano-medley_solos-3976.wav'],
#  ['violin', 'clarinet-good_sounds-003058.wav'],
#  ['voice', 'guitar_acoustic-irmas-3989.wav'],
#  ['cello', 'flute-irmas-5288.wav'],
#  ['violin', 'sax_soprano-good_sounds-011110.wav'],
#  ['violin', 'trumpet-irmas-1730.wav'],
#  ['cello', 'guitar_electric-irmas-6241.wav'],
#  ['organ', 'voice-irmas-973.wav'],
#  ['clarinet', 'sax_soprano-good_sounds-011557.wav'],
#  ['clarinet', 'organ-irmas-3003.wav'],
#  ['sax_tenor', 'sax_alto-good_sounds-009666.wav'],
#  ['voice', 'violin-medley_solos-8171.wav'],
#  ['organ', 'voice-irmas-1370.wav'],
#  ['guitar_electric', 'voice-irmas-1442.wav'],
#  ['clarinet', 'guitar_acoustic-irmas-4516.wav'],
#  ['sax_alto', 'sax_soprano-good_sounds-011130.wav'],
#  ['flute', 'piano-medley_solos-9919.wav'],
#  ['guitar_electric', 'voice-irmas-1191.wav'],
#  ['violin', 'cello-good_sounds-002260.wav'],
#  ['sax_baritone', 'piano-medley_solos-1048.wav'],
#  ['trumpet', 'guitar_acoustic-irmas-4107.wav'],
#  ['piano', 'clarinet-irmas-3577.wav'],
#  ['clarinet', 'flute-irmas-5310.wav'],
#  ['guitar_electric', 'organ-irmas-3075.wav'],
#  ['cello', 'piano-irmas-377.wav'],
#  ['organ', 'flute-irmas-5473.wav'],
#  ['voice', 'guitar_electric-irmas-6005.wav'],
#  ['guitar_acoustic', 'saxophone-irmas-2308.wav'],
#  ['clarinet', 'flute-medley_solos-7387.wav'],
#  ['sax_baritone', 'clarinet-irmas-3513.wav'],
#  ['piano', 'clarinet-irmas-3523.wav'],
#  ['trumpet', 'sax_soprano-good_sounds-011032.wav'],
#  ['clarinet', 'piano-irmas-139.wav'],
#  ['piano', 'trumpet-irmas-1718.wav'],
#  ['organ', 'voice-irmas-880.wav'],
#  ['guitar_electric', 'trumpet-irmas-1799.wav'],
#  ['violin', 'clarinet-good_sounds-002760.wav'],
#  ['cello', 'violin-good_sounds-015176.wav'],
#  ['piano', 'guitar_acoustic-irmas-3916.wav'],
#  ['piano', 'flute-medley_solos-1938.wav'],
#  ['flute', 'clarinet-medley_solos-2841.wav'],
#  ['piano', 'guitar_electric-medley_solos-4104.wav'],
#  ['sax_soprano', 'flute-good_sounds-006683.wav'],
#  ['sax_tenor', 'trumpet-good_sounds-012937.wav'],
#  ['piano', 'guitar_electric-irmas-5667.wav'],
#  ['violin', 'cello-irmas-6491.wav'],
#  ['voice', 'violin-irmas-4760.wav'],
#  ['cello', 'violin-medley_solos-11408.wav'],
#  ['voice', 'flute-medley_solos-4606.wav'],
#  ['saxophone', 'voice-irmas-1118.wav'],
#  ['cello', 'organ-irmas-3324.wav'],
#  ['flute', 'clarinet-good_sounds-004342.wav'],
#  ['clarinet', 'sax_alto-good_sounds-009393.wav'],
#  ['clarinet', 'flute-good_sounds-005987.wav'],
#  ['guitar_electric', 'sax_soprano-good_sounds-010947.wav'],
#  ['flute', 'sax_soprano-good_sounds-011534.wav'],
#  ['clarinet', 'violin-medley_solos-5979.wav'],
#  ['violin', 'clarinet-irmas-3788.wav'],
#  ['voice', 'guitar_electric-irmas-6262.wav'],
#  ['clarinet', 'piano-medley_solos-308.wav'],
#  ['organ', 'voice-irmas-863.wav'],
#  ['flute', 'piano-medley_solos-12849.wav'],
#  ['organ', 'guitar_electric-irmas-5767.wav'],
#  ['flute', 'clarinet-good_sounds-002324.wav'],
#  ['clarinet', 'guitar_electric-irmas-5966.wav'],
#  ['sax_soprano', 'sax_baritone-good_sounds-010398.wav'],
#  ['clarinet', 'sax_tenor-good_sounds-012547.wav'],
#  ['organ', 'piano-irmas-670.wav'],
#  ['cello', 'violin-irmas-4884.wav'],
#  ['trumpet', 'piano-medley_solos-9260.wav'],
#  ['voice', 'guitar_electric-irmas-6291.wav'],
#  ['flute', 'trumpet-irmas-1959.wav'],
#  ['sax_tenor', 'sax_alto-good_sounds-009681.wav'],
#  ['violin', 'guitar_acoustic-irmas-4494.wav'],
#  ['sax_tenor', 'violin-good_sounds-014964.wav'],
#  ['cello', 'saxophone-irmas-2640.wav'],
#  ['trumpet', 'clarinet-good_sounds-003483.wav'],
#  ['sax_tenor', 'violin-medley_solos-4988.wav'],
#  ['piano', 'clarinet-medley_solos-10706.wav'],
#  ['piano', 'flute-irmas-5149.wav'],
#  ['violin', 'cello-good_sounds-002014.wav'],
#  ['trumpet', 'sax_alto-good_sounds-009653.wav'],
#  ['organ', 'piano-irmas-551.wav'],
#  ['piano', 'cello-irmas-6595.wav'],
#  ['piano', 'clarinet-irmas-3648.wav'],
#  ['cello', 'guitar_electric-medley_solos-13150.wav'],
#  ['flute', 'piano-irmas-51.wav'],
#  ['voice', 'organ-irmas-3356.wav'],
#  ['voice', 'guitar_electric-irmas-5802.wav'],
#  ['flute', 'clarinet-good_sounds-003172.wav'],
#  ['sax_tenor', 'violin-good_sounds-016121.wav'],
#  ['cello', 'violin-irmas-4575.wav'],
#  ['violin', 'voice-irmas-881.wav'],
#  ['piano', 'clarinet-good_sounds-004320.wav'],
#  ['flute', 'trumpet-medley_solos-9200.wav'],
#  ['organ', 'guitar_electric-irmas-5945.wav'],
#  ['violin', 'voice-irmas-866.wav'],
#  ['clarinet', 'flute-good_sounds-005716.wav'],
#  ['sax_baritone', 'flute-good_sounds-006480.wav'],
#  ['piano', 'saxophone-irmas-2104.wav'],
#  ['flute', 'clarinet-irmas-3501.wav'],
#  ['violin', 'saxophone-irmas-2382.wav'],
#  ['voice', 'clarinet-irmas-3498.wav'],
#  ['violin', 'flute-good_sounds-006730.wav'],
#  ['cello', 'guitar_acoustic-irmas-4145.wav'],
#  ['voice', 'saxophone-irmas-2576.wav'],
#  ...]
